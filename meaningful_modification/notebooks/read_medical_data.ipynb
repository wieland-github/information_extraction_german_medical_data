# %% [markdown]
# # Offizielle Diagnisosen
# - damit kann LLM später nicht Diagnosen Halluzinieren, da vorgegeben

# %%
import pandas as pd
import csv
from pathlib import Path

# %% [markdown]
# ## ICD-10-GM ganauer: Alpha-ID-SE

# %%
eingabe = Path(
    "/Users/wielandcremer/Downloads/alphaidse2026/"
    "icd10gm2026_alphaidse_edvtxt_20250926.txt"
)

ausgabe = Path(
    "/Users/wielandcremer/Dokumente/Uni/6_Semester/"
    "information_extraction_german_medical_data/"
    "meaningful_modification/data/medical_information/"
    "Alpha-ID-SE.csv"
)

ausgabe.parent.mkdir(parents=True, exist_ok=True)

anzahl = 0

with (
    eingabe.open("r", encoding="utf-8") as quelle,
    ausgabe.open("w", encoding="utf-8-sig", newline="") as ziel
):
    writer = csv.writer(
        ziel,
        delimiter=";",
        quotechar='"',
        quoting=csv.QUOTE_MINIMAL
    )

    writer.writerow(["ICD_Code", "Diagnose"])

    for zeilennummer, zeile in enumerate(quelle, start=1):
        spalten = zeile.rstrip("\r\n").split("|")

        if len(spalten) < 8:
            print(f"Zeile {zeilennummer} übersprungen")
            continue

        icd_code = spalten[5].strip()
        diagnose = spalten[7].strip()

        if icd_code and diagnose:
            writer.writerow([icd_code, diagnose])
            anzahl += 1

print(f"{anzahl} Diagnosen gespeichert unter: {ausgabe}")
# Out:
# 692 Diagnosen gespeichert unter: /Users/wielandcremer/Dokumente/Uni/6_Semester/information_extraction_german_medical_data/meaningful_modification/data/medical_information/Alpha-ID-SE.csv

# %%
AlphaIDSE = pd.read_csv(
    ausgabe,
    sep=";",
    encoding="utf-8-sig",
    dtype=str
)

# %%
print(AlphaIDSE.head())
# Out:
#   ICD_Code                                           Diagnose
# 0      E86  Diarrhoe, vermutlich infektiösen Ursprungs, mi...
# 1      E86  Enteritis, vermutlich infektiösen Ursprungs, m...
# 2      E86  Gastroenteritis, vermutlich infektiösen Urspru...
# 3      E86                  Infektiöse Diarrhoe mit Exsikkose
# 4      E86           Infektiöse Gastroenteritis mit Exsikkose

# %% [markdown]
# # Medikament und Wirktoff

# %%
whoACTddd = pd.read_csv("/Users/wielandcremer/Dokumente/Uni/6_Semester/information_extraction_german_medical_data/meaningful_modification/data/medical_information/who_atc_ddd.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 whoACTddd = pd.read_csv("/Users/wielandcremer/Dokumente/Uni/6_Semester/information_extraction_german_medical_data/meaningful_modification/data/medical_information/who_atc_ddd.csv")
#
# File /opt/miniconda3/envs/spacy-test/lib/python3.11/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/envs/spacy-test/lib/python3.11/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File /opt/miniconda3/envs/spacy-test/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/envs/spacy-test/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File /opt/miniconda3/envs/spacy-test/lib/python3.11/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/wielandcremer/Dokumente/Uni/6_Semester/information_extraction_german_medical_data/meaningful_modification/data/medical_information/who_atc_ddd.csv'

# %%
whoACTddd.head()
# Out:
#   atc_code                         atc_name  ddd  uom adm_r             note
# 0        A  ALIMENTARY TRACT AND METABOLISM  NaN  NaN   NaN              NaN
# 1      A01      STOMATOLOGICAL PREPARATIONS  NaN  NaN   NaN              NaN
# 2     A01A      STOMATOLOGICAL PREPARATIONS  NaN  NaN   NaN              NaN
# 3    A01AA       Caries prophylactic agents  NaN  NaN   NaN              NaN
# 4  A01AA01                  sodium fluoride  1.1   mg     O  0.5 mg fluoride

# %%
whoACTddd_new = whoACTddd.dropna(subset="uom")
whoACTddd_new = whoACTddd.dropna(subset="ddd")
whoACTddd_new.head()
print(whoACTddd_new["atc_name"].count())
# Out:
# 2559

# %% [markdown]
# # ICD-10-GM

# %%
eingabe = Path(
    "/Users/wielandcremer/Downloads/icd10gm2026syst-meta/Klassifikationsdateien/icd10gm2026syst_kodes.txt"
)

ausgabe = Path(
    "/Users/wielandcremer/Dokumente/Uni/6_Semester/"
    "information_extraction_german_medical_data/"
    "meaningful_modification/data/medical_information/"
    "ICD-10-GM.csv"
)

ausgabe.parent.mkdir(parents=True, exist_ok=True)

anzahl = 0
uebersprungen = 0

with (
    eingabe.open("r", encoding="utf-8") as quelle,
    ausgabe.open("w", encoding="utf-8-sig", newline="") as ziel
):
    writer = csv.writer(
        ziel,
        delimiter=";",
        quotechar='"',
        quoting=csv.QUOTE_MINIMAL
    )

    writer.writerow(["ICD_Code", "Diagnose"])

    for zeilennummer, zeile in enumerate(quelle, start=1):
        spalten = zeile.rstrip("\r\n").split(";")

        if len(spalten) < 9:
            print(f"Zeile {zeilennummer} übersprungen: zu wenige Spalten")
            uebersprungen += 1
            continue

        terminal = spalten[1].strip()
        icd_code = spalten[5].strip()
        diagnose = spalten[8].strip()

        # Nur endständige und damit kodierbare ICD-10-GM-Codes speichern
        if terminal != "T":
            continue

        if icd_code and diagnose:
            writer.writerow([icd_code, diagnose])
            anzahl += 1

print(f"{anzahl} Diagnosen gespeichert unter: {ausgabe}")
print(f"{uebersprungen} fehlerhafte Zeilen übersprungen")
# Out:
# 14370 Diagnosen gespeichert unter: /Users/wielandcremer/Dokumente/Uni/6_Semester/information_extraction_german_medical_data/meaningful_modification/data/medical_information/ICD-10-GM.csv
# 0 fehlerhafte Zeilen übersprungen
